# %%
from pathlib import Path
import sys

# Find project root (the folder that contains "src")
ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent

sys.path.insert(0, str(ROOT))

from src.data import prepare_data, DataConfig

# %%
bundle = prepare_data(DataConfig(raw_path="../data/raw/telco.csv"))
bundle["X_train_mat"].shape
# Out:
# (4929, 45)
