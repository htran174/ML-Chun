# %%
import sys
import torch
import os
print(sys.version)
print(torch.__version__)
print(os.getcwd())
# Out:
# 3.12.12 (main, Oct  9 2025, 11:07:00) [Clang 17.0.0 (clang-1700.6.3.2)]
# 2.10.0
# /Users/hientran/Desktop/ML-Chun/notebooks

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/telco.csv")

# %%
df.shape
# Out:
# (7043, 21)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
#Check customerID uniqueness
df.shape[0]
# Out:
# 7043

# %%
df["customerID"].nunique()
# Out:
# 7043

# %%
df["TotalCharges"].str.strip() == ""
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
# number of blanks
blank_mask = df["TotalCharges"].str.strip() == ""
blank_mask.sum()
# Out:
# np.int64(11)

# %%
df[blank_mask].head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# 753           Yes                No              No  No internet service  ...
# 936           Yes                No             DSL                  Yes  ...
# 1082          Yes               Yes              No  No internet service  ...
# 1340           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df[blank_mask]["tenure"].value_counts()
# Out:
# tenure
# 0    11
# Name: count, dtype: int64

# %%
#changing the blank total charges into 0
df.loc[blank_mask, "TotalCharges"] = "0"

# %%
blank_mask = df["TotalCharges"].str.strip() == ""
blank_mask.sum()
# Out:
# np.int64(0)

# %%
#convert total charge col into numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"])

# %%
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
#checking if there are any missing value in cols
missing_count = df.isna().sum()
missing_pct = df.isna().mean() * 100
print(missing_count)
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
numeric_cols = ["tenure", "MonthlyCharges", "TotalCharges", "SeniorCitizen"]

# %%
#sanity check numeric cols
df[numeric_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges  SeniorCitizen
# count  7043.000000     7043.000000   7043.000000    7043.000000
# mean     32.371149       64.761692   2279.734304       0.162147
# std      24.559481       30.090047   2266.794470       0.368612
# min       0.000000       18.250000      0.000000       0.000000
# 25%       9.000000       35.500000    398.550000       0.000000
# 50%      29.000000       70.350000   1394.550000       0.000000
# 75%      55.000000       89.850000   3786.600000       0.000000
# max      72.000000      118.750000   8684.800000       1.000000

# %%
#Categorical Sanity Check
categorical_cols = df.columns.difference(numeric_cols)
for col in categorical_cols:
    print(f"\nColumn: {col}")
    print(df[col].value_counts())
# Out:
# Column: Churn
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Column: Contract
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# Column: Dependents
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# Column: DeviceProtection
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
#
# Column: InternetService
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# Column: MultipleLines
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# Column: OnlineBackup
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# Column: OnlineSecurity
# OnlineSecurity
# No                     3498
# ...

# %% [markdown]
# Categorical Sanity Check Conclusion
#
# All categorical columns contain clean, consistent values.
#
# No casing inconsistencies or trailing spaces detected.
#
# Categories such as "No internet service" and "No phone service" represent valid structural categories and will be retained.
#
# customerID identified as identifier column and will be excluded from modeling.

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_binary = df["Churn"].map({"Yes": 1, "No": 0})

# %%
#for numic
df.groupby("Churn")["tenure"].mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
#for calorial
df.groupby("DeviceProtection")["Churn"].apply(lambda x: (x == "Yes").mean())
# Out:
# DeviceProtection
# No                     0.391276
# No internet service    0.074050
# Yes                    0.225021
# Name: Churn, dtype: float64

# %% [markdown]
# Basic demographic and add-on entertainment features show limited separation in churn rates.
#
# Very Strong Signals
# Contract, Tenure, InternetService, OnlineSecurity, TechSupport, DeviceProtection
#
# Moderate Signals
# Partner, Dependents, SeniorCitizen

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...
